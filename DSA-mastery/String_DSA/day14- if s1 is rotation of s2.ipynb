# %%
def are_rotations(s1,s2):
    n=len(s1)
    for i in range(n):
        if s1==s2:
            return True
        s1= s1[-1]+s1[:-1]
        print(s1)
    return False

s1="aab"
s2="aba"
print(are_rotations(s1,s2))
