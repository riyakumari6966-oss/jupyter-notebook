# %%
#my approach (wrong)
nums=[-4,-1,0,3,10]
nums1=[]
for i in range(len(nums)):
    nums[i]=nums[i]**2
    nums1.append(nums[i])
    left=0
    right=len(nums1)-1
    while left<right:
        if nums1[left]>nums1[right]:
            nums1[left],nums1[right]=nums1[right],nums1[left]
            left+=1
        else:
            right-=1
print(nums1)
    
#correct approach
nums=[-4,-1,0,3,10]
n=len(nums)                #length of the array
left=0                     #pointer at the beginning of the array
right=n-1                  #pointer at the end of the array
num=[0]*n                  #resultant array to store the squares of the numbers
for i in range(n-1,-1,-1): #traverse the array from the end to the beginning
    if abs(nums[left])>abs(nums[right]): #compare the absolute values of the numbers at the left and right pointers
        num[i]=nums[left]**2     #store the square of the number at the left pointer in the resultant array
        left+=1                  #move the left pointer to the right
    else:
        num[i]=nums[right]**2    #store the square of the number at the right pointer in the resultant array
        right-=1                 #move the right pointer to the left
print(num)
# Out:
# [0, 1, 16, 9, 100]
# [0, 1, 9, 16, 100]
