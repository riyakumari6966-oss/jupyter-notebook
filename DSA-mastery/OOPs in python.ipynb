# %%
class Student:
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
        print("Student Name:",self.name)
        print("Marks:",self.marks)

    def average(self):
        avg=sum(self.marks)/len(self.marks)
        print("HI",self.name,"you avg score is:",avg)

student1=Student("Alice",[86,98,90])
student1.average()
student1.name="Bob"
student1.average()
# Out:
# Student Name: Alice
# Marks: [86, 98, 90]
# HI Alice you avg score is: 91.33333333333333
# HI Bob you avg score is: 91.33333333333333

# %%
#bank balance 
class BankAccount:
    def __init__(self,account_number,balance=0):
        self.account_number=account_number
        self.balance=balance
        print("Account Number:",self.account_number)
        print("Current Balance:",self.balance)
        
    def deposite(self,amount):
        self.balance+=amount
        print("Deposited:",amount)
        print("New Balance:",self.balance)
    
    def withdraw(self,amount):
        if amount>self.balance:
            print("Insufficient Funds")
        else:
            self.balance-=amount
            print("Withdrawn:",amount)
            print("New balance:",self.balance)
account1=BankAccount("12345",2000)
account1.deposite(500)
account1.withdraw(1000)
# Out:
# Account Number: 12345
# Current Balance: 2000
# Deposited: 500
# New Balance: 2500
# Withdrawn: 1000
# New balance: 1500

# %%
class Car:
    @staticmethod
    def start():
        print("Car is starting...")
    @staticmethod
    def stop():
        print("Car is stopping...")

class ToyotaCar(Car):
    def __init__(self,model):
        self.model=model
        print("Toyota Car Model:",self.model)
    
toyota1=ToyotaCar("Camry")
toyota1.start()
# Out:
# Toyota Car Model: Camry
# Car is starting...

# %%
#polymorphism: ek hi chiz ke bahot sare forms
#operator overloading (implicit overloading)
print(1+2) # here plus is used to add two numbers
print("Hello"+" "+"World") # here plus is used to concatenate two strings
print([1,2,3]+[4,5,6]) # here plus is used to concatenate two lists
# Out:
# 3
# Hello World
# [1, 2, 3, 4, 5, 6]

# %%
#operator overloading (implicit overloading)
class Complex:
    def __init__(self,real,imaginary):
        self.real=real
        self.imaginary=imaginary
    
    def showNumber(self):
        print(self.real,"i +", self.imaginary,"j")
    
    def __add__(self,num2):
        newReal=self.real+num2.real
        newImaginary=self.imaginary+num2.imaginary
        return Complex(newReal,newImaginary) 
    def __sub__(self,num2):
        newReal=self.real-num2.real
        newImaginary=self.imaginary-num2.imaginary
        return Complex(newReal,newImaginary)
    
num1=Complex(2,3)
num2=Complex(4,5)
num3=num1+num2
print(num3.showNumber())
num4=num1-num2
print(num4.showNumber())
# Out:
# 6 i + 8 j
# None
# -2 i + -2 j
# None

# %%
class Circle:
    def __init__(self,radius):
        self.radius=radius
        print("Circle with radius:",self.radius)
    def area(self):
        area=3.14*self.radius**2
        print("Area of Circle:",area)

    def perimeter(self):
        perimeter=2*3.14*self.radius
        print("Perimeter of Circle:",perimeter)

circle=Circle(5)
circle.area()
circle.perimeter()
# Out:
# Circle with radius: 5
# Area of Circle: 78.5
# Perimeter of Circle: 31.400000000000002

# %%
#Employee Management System
class Employee:
    def __init__(self,name,role, department, salary):
        self.name=name
        self.role=role
        self.department=department
        self.salary=salary
    def displayDetails(self):
        print("Employee Name:",self.name)
        print("Role:",self.role)
        print("Department:",self.department)
        print("Salary:",self.salary)

class Engineer(Employee):
    def __init__(self,age):
        self.age=age
        super().__init__("Alice","Engineer","yoyo",800000)


eng=Engineer(25)
eng.displayDetails()
# Out:
# Employee Name: Alice
# Role: Engineer
# Department: yoyo
# Salary: 800000

# %%
class Product:
    def __init__(self, name, price):
        self.name=name
        self.price=price
class Cart:
    def __init__(self):
        self.items=[]
    def add_product(self,product_obj):
        self.items.append(product_obj)
        print(f"Added {product_obj.name} to cart at price {product_obj.price}")

pdt1=Product("Laptop",1000)
mycart=Cart()
mycart.add_product(pdt1)
# Out:
# Added Laptop to cart at price 1000

# %%
class Time:
    def __init__(self, hours, minutes):
        self.hours=hours
        self.minutes=minutes
    
    def add(self,other_time):
        total_minutes=self.minutes+other_time.minutes
        total_hours=self.hours+other_time.hours+total_minutes//60
        total_minutes=total_minutes%60
        return Time(total_hours,total_minutes)
    
    def __str__(self):
        return f"{self.hours} hours and {self.minutes} minutes"

t1=Time(2,45)
t2=Time(3,30)
total=t1.add(t2) 
print("Total Cumulative Time:",total)
# Out:
# Total Cumulative Time: 6 hours and 15 minutes

# %%
class Point:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def __str__(self):
        return f"Point({self.x},{self.y})"
class PointFactory:
    def create_midpoint(self,p1,p2):
        mx=(p1.x+p2.x)/2
        my=(p1.y+p2.y)/2
        return Point(mx,my)
p1=Point(2,3)
p2=Point(4,5)
factory=PointFactory()
midpoint=factory.create_midpoint(p1,p2) #point class is interacting with point factory class to create midpoint
print("Midpoint:",midpoint)

# %%
class Product:
    def __init__(self,name,price):
        self.name=name
        self.price=price
    def __str__(self):
        return f"Product Name: {self.name}, Price: {self.price}"
    
class ShoppingApp:
    def __init__(self):
        self.cart=[]
    
    def add_cart(self,product):
        self.cart.append(product)
        print(f"Added {product.name} to cart at price {product.price}")
    
    def view_cart(self):
        print("-----cart items-----")
        for item in self.cart:
            print(item)
app= ShoppingApp()
pd1=Product("Laptop",1000)
app.add_cart(pd1)
app.view_cart()
# Out:
# Added Laptop to cart at price 1000
# -----cart items-----
# Product Name: Laptop, Price: 1000

# %%
class Rectangle:
    def __init__(self,corner,length,width):
        self.corner=corner
        self.length=length
        self.width=width
    def grow(self,delta_length,delta_width):
        self.length+=delta_length
        self.width+=delta_width
        print(f"Rectangle grew to length: {self.length} and width: {self.width}")
    def move(self,dx,dy):
        self.corner.x+=dx
        self.corner.y+=dy
        print(f"Rectangle moved to new corner: ({self.corner.x},{self.corner.y})")

rect=Rectangle(Point(0,0),4,2)
rect.grow(2,1)
rect.move(1,1)
# Out:
# Rectangle grew to length: 6 and width: 3
# Rectangle moved to new corner: (1,1)

# %%
a=[1,2]
b=[1,2]
c=a
print(a is b)
print(a==b)
print(a is c)
# Out:
# False
# True
# True

# %%
class Point:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def same_point(self,p2):
        return self.x==p2.x and self.y==p2.y
p1=Point(2,3)
p2=Point(2,3)
print(p1.same_point(p2))
# Out:
# True

# %%
numbers=[10,20,30]
try:
    index=int(input("Enter index to access between(0 to 2):"))
    number=f"Element at index {index}:{numbers[index]}"
    
    divisor=int(input("Enter a number to divide by 100:"))
    division=100/divisor
    print(f"Division result: {division}")

except ZeroDivisionError:
    print("Cannot divide by zero")
except IndexError:
    print("Index out of range")
# Out:
# Cannot divide by zero

# %%
try:
    number=int(input("enter a number:"))
except ValueError:
    print("Invalid input! Please enter a valid number.")
else:
    print(number**2)
finally:
    print("thank you")
# Out:
# Invalid input! Please enter a valid number.
# thank you

# %%
def get_age():
    age=int(input("enter your age:"))
    if age<0:
        myerror=ValueError(f"{age} is not a valid age")
        raise myerror
    return age
try:
    valid_age=get_age()
    print(f"your age is valid:{age}")
except ValueError as e:
    print(f"Caught and exception:{e}")
# Out:
# Caught and exception:-20 is not a valid age

# %%
class Car:
    def __init__(self,brand):
        self.brand=brand
    def start(self):
        print("car started..")
    def stop(self):
        print("car stopped")

class Toyota(Car):
    def __init__(self,model):
        self.model=model
        print(model)
mod=Toyota("hairss")
mod.start()
# Out:
# hairss
# car started..

# %%
class MyTime:
    def __init__(self,h,m,s):
        self.hours=h
        self.minutes=m
        self.seconds=s
    def add_time(self,t2):
        h=self.hours + t2.hours
        m=self.minutes + t2.minutes
        s=self.seconds + t2.seconds
        sum_t=MyTime(h,m,s)
        return sum_t
    def __str__(self):
        return f"{self.hours:02d}:{self.minutes:02d}:{self.seconds:02d}"
current_time=MyTime(2,30,20)
bread_time=MyTime(3,45,34)
done_time=current_time.add_time(bread_time)
print(done_time)
# Out:
# 05:75:54

# %%
class MyTime:
    def __init__(self,h,m,s):
        self.hours=h
        self.minutes=m
        self.seconds=s
    def do_seconds(self):
        return self.hours *3600 +self.minutes *60 +self.seconds

def add_time(t1,t2):
    total_seconds=t1.do_seconds()+t2.do_seconds()
    h=total_seconds//3600
    m=(total_seconds%3600)//60
    s=total_seconds%60

    return MyTime(h,m,s)
current_time=MyTime(2,30,20)
bread_time=MyTime(3,45,34)
done_time=add_time(current_time,bread_time)
print(f"finishing time {done_time.hours}:{done_time.minutes}:{done_time.seconds}")
# Out:
# finishing time 6:15:54

# %%
class Coordinates:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def __add__(self,other):
        return Coordinates(self.x+other.x, self.y+other.y)
    def __str__(self):
        return f"{self.x},{self.y}"
p1=Coordinates(1,2)
p2=Coordinates(3,4)
p3=p1+p2
print(p3)
# Out:
# 4,6

# %%
import numpy as np
b=np.array([200,230,150,260,90])
mask= b>200
print("the mask boolean value:",mask)
filtered_data=b[mask]
print("filtered_data")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 b=np.array([200,230,150,260,90])
#       3 mask= b>200
#       4 print("the mask boolean value:",mask)
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy as np
data=np.array([20,30,60,180,140,100])
combines_mask=(data%2==0) and (data>50)
result=data[combines_mask]
print(result)

# %%
import numpy as np
matrix2D=np.array([2,3],[4,5],[5,6])

matrix1D=np.array([1,10])
broadcasted_add=matrix2D+matrix1D # array 1 D streches downwards to match 3 rows
print(broadcasted_add)

# %%
class Student:
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
    def avg(self):
        average=(sum(self.marks))/(len(self.marks))
        return average
class Student_System:
    def __init__(self):
        self.student=[]
    def add_student(self,name,marks):
        s=Student(name,marks)
        self.student.append(s)
    def show_report(self):
        for s in self.student:
            print(f"Name:{s.name}, average={s.avg():.2f}")

sms=Student_System()
sms.add_student("Reshika",[91,90,98])
sms.add_student("varnika",[80,90,99])
sms.show_report()
# Out:
# Name:Reshika, average=93.00
# Name:varnika, average=89.67

# %%
class Student:
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
    def get_avg(self):
        return sum(self.marks)/len(self.marks)
class Student_System:
    def __init__(self):
        self.student=[]
    def add_student(self,name,marks):
        s=Student(name,marks)
        self.student.append(s)
    def display(self):
        for s in self.student:
            print(f"Name:{s.name},avg:{s.get_avg():.2f}")
sms=Student_System()
sms.add_student("Reshika",[91,90,98])
sms.add_student("varnika",[80,90,99])
sms.display()
# Out:
# Name:Reshika,avg:93.00
# Name:varnika,avg:89.67

# %%
class Pateint:
    def __init__(self,name,illness):
        self.name=name
        self.illness=illness
class Doctor:
    def __init__(self,name,sepciality):
        self.name=name
        self.speciality=speciality
class Appointment:
    def __init__(self,pateint_obj,doctor_obj,time)
        

    def show(self)
